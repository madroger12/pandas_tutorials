# %%
import pandas as pd
df = pd.read_csv('stack_unstack.csv',header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    price Unnamed: 2_level_0 Unnamed: 3_level_0  \
#              company facebook             google          microsoft
# 0           05/06/17      155                955                 66
# 1           06/06/17      150                987                 69
# 2           07/06/17      153                963                 62
# 3           08/06/17      155               1000                 61
# 4           09/06/17      156               1012                 66
#
#   price to earning ratio Unnamed: 5_level_0 Unnamed: 6_level_0
#                 facebook             google          microsoft
# 0                  37.10               32.0              30.31
# 1                  36.98               31.3              30.56
# 2                  36.78               31.7              30.46
# 3                  36.11               31.2              30.11
# 4                  37.07               30.0              31.00

# %%
df.stack()
# Out:
#             Unnamed: 0_level_0  Unnamed: 2_level_0  Unnamed: 3_level_0  \
# 0 company             05/06/17                 NaN                 NaN
#   facebook                 NaN                 NaN                 NaN
#   google                   NaN               955.0                 NaN
#   microsoft                NaN                 NaN                66.0
# 1 company             06/06/17                 NaN                 NaN
#   facebook                 NaN                 NaN                 NaN
#   google                   NaN               987.0                 NaN
#   microsoft                NaN                 NaN                69.0
# 2 company             07/06/17                 NaN                 NaN
#   facebook                 NaN                 NaN                 NaN
#   google                   NaN               963.0                 NaN
#   microsoft                NaN                 NaN                62.0
# ...

# %%
df.stack(level=0)
# Out:
#                            company  facebook  google  microsoft
# 0 Unnamed: 0_level_0      05/06/17       NaN     NaN        NaN
#   Unnamed: 2_level_0           NaN       NaN   955.0        NaN
#   Unnamed: 3_level_0           NaN       NaN     NaN      66.00
#   Unnamed: 5_level_0           NaN       NaN    32.0        NaN
#   Unnamed: 6_level_0           NaN       NaN     NaN      30.31
#   price                        NaN    155.00     NaN        NaN
#   price to earning ratio       NaN     37.10     NaN        NaN
# 1 Unnamed: 0_level_0      06/06/17       NaN     NaN        NaN
#   Unnamed: 2_level_0           NaN       NaN   987.0        NaN
#   Unnamed: 3_level_0           NaN       NaN     NaN      69.00
#   Unnamed: 5_level_0           NaN       NaN    31.3        NaN
#   Unnamed: 6_level_0           NaN       NaN     NaN      30.56
#   price                        NaN    150.00     NaN        NaN
#   price to earning ratio       NaN     36.98     NaN        NaN
# ...

# %%
df_stacked = df.stack()
df_stacked
# Out:
#             Unnamed: 0_level_0  Unnamed: 2_level_0  Unnamed: 3_level_0  \
# 0 company             05/06/17                 NaN                 NaN
#   facebook                 NaN                 NaN                 NaN
#   google                   NaN               955.0                 NaN
#   microsoft                NaN                 NaN                66.0
# 1 company             06/06/17                 NaN                 NaN
#   facebook                 NaN                 NaN                 NaN
#   google                   NaN               987.0                 NaN
#   microsoft                NaN                 NaN                69.0
# 2 company             07/06/17                 NaN                 NaN
#   facebook                 NaN                 NaN                 NaN
#   google                   NaN               963.0                 NaN
#   microsoft                NaN                 NaN                62.0
# ...

# %%
df_stacked.unstack()
# Out:
#   Unnamed: 0_level_0                           Unnamed: 2_level_0           \
#              company facebook google microsoft            company facebook
# 0           05/06/17      NaN    NaN       NaN                NaN      NaN
# 1           06/06/17      NaN    NaN       NaN                NaN      NaN
# 2           07/06/17      NaN    NaN       NaN                NaN      NaN
# 3           08/06/17      NaN    NaN       NaN                NaN      NaN
# 4           09/06/17      NaN    NaN       NaN                NaN      NaN
#
#                     Unnamed: 3_level_0           ... Unnamed: 6_level_0  \
#    google microsoft            company facebook  ...             google
# 0   955.0       NaN                NaN      NaN  ...                NaN
# 1   987.0       NaN                NaN      NaN  ...                NaN
# 2   963.0       NaN                NaN      NaN  ...                NaN
# 3  1000.0       NaN                NaN      NaN  ...                NaN
# ...
